# %%
import pandas as pd

# %%
data=pd.read_csv(r"c:\Users\shali\Downloads\classification_data.csv")
data
# Out:
#        count_session  count_hit channelGrouping  totals_newVisits  \
# 0                  9       1194         (Other)                 0
# 1                  9       1194         (Other)                 0
# 2                 28       1816     Paid Search                 0
# 3                  2        299     Paid Search                 0
# 4                  2        299     Paid Search                 0
# ...              ...        ...             ...               ...
# 99995             58      12340     Paid Search                 0
# 99996             58      12340     Paid Search                 0
# 99997             58      12340     Paid Search                 0
# 99998             58      12340     Paid Search                 0
# 99999             58      12340     Paid Search                 0
#
#         device_browser device_operatingSystem  device_isMobile  \
# 0      GoogleAnalytics                Android             True
# ...

# %%
data.dtypes
# Out:
# count_session               int64
# count_hit                   int64
# channelGrouping            object
# totals_newVisits            int64
# device_browser             object
# device_operatingSystem     object
# device_isMobile              bool
# device_deviceCategory      object
# geoNetwork_region          object
# geoNetwork_latitude       float64
# geoNetwork_longitude      float64
# historic_session            int64
# historic_session_page       int64
# youtube                     int64
# avg_session_time          float64
# avg_session_time_page     float64
# single_page_rate          float64
# sessionQualityDim           int64
# last_visitId                int64
# latest_visit_id             int64
# visitId_threshold           int64
# earliest_visit_id           int64
# earliest_visit_number       int64
# latest_visit_number         int64
# time_earliest_visit       float64
# time_latest_visit         float64
# avg_visit_time              int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   count_session           100000 non-null  int64
#  1   count_hit               100000 non-null  int64
#  2   channelGrouping         100000 non-null  object
#  3   totals_newVisits        100000 non-null  int64
#  4   device_browser          100000 non-null  object
#  5   device_operatingSystem  100000 non-null  object
#  6   device_isMobile         100000 non-null  bool
#  7   device_deviceCategory   100000 non-null  object
#  8   geoNetwork_region       100000 non-null  object
#  9   geoNetwork_latitude     100000 non-null  float64
#  10  geoNetwork_longitude    100000 non-null  float64
#  11  historic_session        100000 non-null  int64
#  12  historic_session_page   100000 non-null  int64
#  13  youtube                 100000 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['count_session', 'count_hit', 'channelGrouping', 'totals_newVisits',
#        'device_browser', 'device_operatingSystem', 'device_isMobile',
#        'device_deviceCategory', 'geoNetwork_region', 'geoNetwork_latitude',
#        'geoNetwork_longitude', 'historic_session', 'historic_session_page',
#        'youtube', 'avg_session_time', 'avg_session_time_page',
#        'single_page_rate', 'sessionQualityDim', 'last_visitId',
#        'latest_visit_id', 'visitId_threshold', 'earliest_visit_id',
#        'earliest_visit_number', 'latest_visit_number', 'time_earliest_visit',
#        'time_latest_visit', 'avg_visit_time', 'days_since_last_visit',
#        'days_since_first_visit', 'visits_per_day', 'bounce_rate',
#        'earliest_source', 'latest_source', 'earliest_medium', 'latest_medium',
#        'earliest_keyword', 'latest_keyword', 'earliest_isTrueDirect',
#        'latest_isTrueDirect', 'num_interactions', 'bounces', 'time_on_site',
# ...

# %%
data.isna().sum()
# Out:
# count_session             0
# count_hit                 0
# channelGrouping           0
# totals_newVisits          0
# device_browser            0
# device_operatingSystem    0
# device_isMobile           0
# device_deviceCategory     0
# geoNetwork_region         0
# geoNetwork_latitude       0
# geoNetwork_longitude      0
# historic_session          0
# historic_session_page     0
# youtube                   0
# avg_session_time          0
# avg_session_time_page     0
# single_page_rate          0
# sessionQualityDim         0
# last_visitId              0
# latest_visit_id           0
# visitId_threshold         0
# earliest_visit_id         0
# earliest_visit_number     0
# latest_visit_number       0
# time_earliest_visit       0
# time_latest_visit         0
# avg_visit_time            0
# days_since_last_visit     0
# days_since_first_visit    0
# visits_per_day            0
# bounce_rate               0
# earliest_source           0
# latest_source             0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['channelGrouping', 'device_browser', 'device_operatingSystem',
#        'device_deviceCategory', 'geoNetwork_region', 'earliest_source',
#        'latest_source', 'earliest_medium', 'latest_medium', 'earliest_keyword',
#        'latest_keyword', 'products_array', 'target_date'],
#       dtype='object')
# Numerical Variables:
# ['count_session', 'count_hit', 'totals_newVisits', 'geoNetwork_latitude', 'geoNetwork_longitude', 'historic_session', 'historic_session_page', 'youtube', 'avg_session_time', 'avg_session_time_page', 'single_page_rate', 'sessionQualityDim', 'last_visitId', 'latest_visit_id', 'visitId_threshold', 'earliest_visit_id', 'earliest_visit_number', 'latest_visit_number', 'time_earliest_visit', 'time_latest_visit', 'avg_visit_time', 'days_since_last_visit', 'days_since_first_visit', 'visits_per_day', 'bounce_rate', 'num_interactions', 'bounces', 'time_on_site', 'transactionRevenue', 'has_converted']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# count_session
# Skew : 3.46
# count_hit
# Skew : 4.01
# totals_newVisits
# Skew : 6.79
# geoNetwork_latitude
# Skew : 0.07
# geoNetwork_longitude
# Skew : -6.97
# historic_session
# Skew : 5.09
# historic_session_page
# Skew : 8.8
# youtube
# Skew : 0.0
# avg_session_time
# Skew : 3.3
# avg_session_time_page
# Skew : 4.06
# single_page_rate
# Skew : -2.37
# sessionQualityDim
# Skew : 1.26
# last_visitId
# Skew : -3.73
# latest_visit_id
# Skew : -3.73
# visitId_threshold
# Skew : -3.73
# earliest_visit_id
# Skew : -2.8
# earliest_visit_number
# Skew : 4.88
# latest_visit_number
# Skew : 30.99
# time_earliest_visit
# Skew : 0.03
# time_latest_visit
# Skew : -0.24
# avg_visit_time
# Skew : -0.05
# days_since_last_visit
# Skew : 0.0
# days_since_first_visit
# Skew : -1.31
# visits_per_day
# Skew : 4.17
# bounce_rate
# Skew : 19.89
# num_interactions
# Skew : 2.94
# bounces
# Skew : 90.19
# time_on_site
# Skew : 8.5
# transactionRevenue
# Skew : 8.77
# has_converted
# Skew : -0.07

# %% [markdown]
# ['channelGrouping', 'device_browser', 'device_operatingSystem',
#        'device_deviceCategory', 'geoNetwork_region', 'earliest_source',
#        'latest_source', 'earliest_medium', 'latest_medium', 'earliest_keyword',
#        'latest_keyword', 'products_array', 'target_date'

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'device_browser', data = data, color = 'blue', 
              order = data['device_browser'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'device_operatingSystem', data = data, color = 'blue', 
              order = data['device_operatingSystem'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'device_deviceCategory', data = data, color = 'blue', 
              order = data['device_deviceCategory'].value_counts().index);
sns.countplot(ax = axes[1, 1], x =  'geoNetwork_region', data = data, color = 'blue', 
              order = data[ 'geoNetwork_region'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'latest_keyword', data = data, color = 'blue', 
              order = data['latest_keyword'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x =  'latest_source', data = data, color = 'blue', 
              order = data[ 'latest_source'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
data_cat=data.select_dtypes(object)

# %%
data_num=data.select_dtypes(["int64","float64"])

# %%
plt.figure(figsize = (25,20))
sns.heatmap(data_num.corr(),annot=True)
plt.show()

# %%
data.shape
# Out:
# (100000, 46)

# %%
data.nunique()
# Out:
# count_session              157
# count_hit                 4506
# channelGrouping              3
# totals_newVisits             2
# device_browser               9
# device_operatingSystem       7
# device_isMobile              2
# device_deviceCategory        3
# geoNetwork_region           91
# geoNetwork_latitude        104
# geoNetwork_longitude       104
# historic_session          6979
# historic_session_page     3066
# youtube                      1
# avg_session_time          8279
# avg_session_time_page     3698
# single_page_rate           493
# sessionQualityDim           67
# last_visitId              9093
# latest_visit_id           9093
# visitId_threshold         9093
# earliest_visit_id         9160
# earliest_visit_number      528
# latest_visit_number        694
# time_earliest_visit       1360
# time_latest_visit         1356
# avg_visit_time              24
# days_since_last_visit        1
# days_since_first_visit      31
# visits_per_day            7794
# ...

# %%
data['channelGrouping'].unique()
# Out:
# array(['(Other)', 'Paid Search', 'Display'], dtype=object)

# %%
data['device_browser'].unique()
# Out:
# array(['GoogleAnalytics', 'Safari', 'Chrome', 'Edge', 'Firefox',
#        'Samsung Internet', 'Opera', 'Android Webview',
#        'Apache-HttpClient'], dtype=object)

# %%
data['device_operatingSystem'].nunique()
# Out:
# 7

# %%
data['historic_session'].unique()
# Out:
# array([ 6504, 12466,  1575, ..., 15860,  1772, 28082], dtype=int64)

# %%
data['geoNetwork_region'].value_counts()
# Out:
# geoNetwork_region
# Dubai                    51481
# Abu Dhabi                33799
# Sharjah                   7214
# Ajman                     4157
# Ras al Khaimah            1298
#                          ...
# Western Province             1
# Nabatiyeh Governorate        1
# Western Cape                 1
# Quebec                       1
# Chandigarh                   1
# Name: count, Length: 91, dtype: int64

# %%
data['geoNetwork_region'].unique()
# Out:
# array(['Sharjah', 'Ajman', 'Abu Dhabi', 'Dubai', 'Ras al Khaimah',
#        '(not set)', 'England', 'Hessen', 'Ash Sharqia Governorate',
#        'Nabatiyeh Governorate', 'Umm Al Quawain', 'Indiana', 'Illinois',
#        'Makkah Province', 'Maharashtra', 'Capital Governorate', 'Jakarta',
#        'Punjab', 'Mount Lebanon Governorate', 'South Holland',
#        'Riyadh Province', 'Ile-de-France', 'Chandigarh', 'Karnataka',
#        'Istanbul', 'Cairo Governorate', 'Andhra Pradesh',
#        'Amman Governorate', 'Beirut Governorate',
#        'Alexandria Governorate', 'New York', 'Ontario', 'Davao Region',
#        'Auvergne-Rhone-Alpes', 'Fujairah', 'Tamil Nadu',
#        'Pays de la Loire', 'Metro Manila', 'Normandy', 'Giza Governorate',
#        'Bavaria', 'Stockholm County', 'Tel Aviv District', 'Vienna',
#        'Decentralized Administration of Peloponnese, Western Greece and the Ionian',
#        'Porto District', 'West Bengal', 'Kerala', 'Lombardy', 'MIMAROPA',
# ...

# %%
data['products_array'].unique()
# Out:
# array(['food////food////food',
# ...

# %%
data["has_converted"].value_counts()
# Out:
# has_converted
# 1    51727
# 0    48273
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x="has_converted", data=data)
plt.title("Target Variable")
plt.show()

# %%
print("percentage of not converted and converted\n",data["has_converted"].value_counts()/len(data)*100)
# Out:
# percentage of not converted and converted
#  has_converted
# 1    51.727
# 0    48.273
# Name: count, dtype: float64

# %%
data['count_session'].unique()
# Out:
# array([  9,  28,   2,   3,   5,  77,  26,  15,  25,  27,  14,   8,   4,
#         16,  17,  47,   1,  11,  10,  37,  49,  40,  18,  51,  22,  13,
#         38,  20,  23,  34,  19,  67,  48,  35,   7,   6,  78,  52,  29,
#         43,  45,  24,  12,  41,  60,  33,  68,  65,  21, 135, 196,  32,
#         42,  79,  31, 105,  36,  30,  44,  90,  88,  50, 106,  54,  94,
#         39, 142,  73,  59, 136,  96,  85, 128, 145, 131, 124,  57, 108,
#         61, 171,  63,  56,  64,  46,  86, 195,  53,  62, 111,  66,  55,
#         76,  71, 119,  72,  74,  58,  69,  70,  91,  98, 143, 187,  95,
#         75, 118, 132, 120,  89, 102,  80, 214, 158, 117, 100, 104,  84,
#        121, 193,  92, 159, 101,  87, 147,  97, 126, 141, 107, 127, 177,
#        110,  81, 114, 221, 133,  93, 138, 203, 116, 125, 134, 152, 112,
#         82, 103, 178,  83, 180, 122, 163, 123, 270, 149,  99, 242, 191,
#        174], dtype=int64)

# %%
data['count_hit'].value_counts()
# Out:
# count_hit
# 500     1447
# 1000     450
# 1679     228
# 496      204
# 1014     201
#         ...
# 1260       1
# 4044       1
# 4700       1
# 337        1
# 1587       1
# Name: count, Length: 4506, dtype: int64

# %%
data['historic_session'].unique()
# Out:
# array([ 6504, 12466,  1575, ..., 15860,  1772, 28082], dtype=int64)

# %%
data['totals_newVisits'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['totals_newVisits'].value_counts()
# Out:
# totals_newVisits
# 0    97962
# 1     2038
# Name: count, dtype: int64

# %%
data['device_isMobile'].unique()
# Out:
# array([ True, False])

# %%
data['device_deviceCategory'].unique()
# Out:
# array(['mobile', 'desktop', 'tablet'], dtype=object)

# %%
data['historic_session_page'].unique()
# Out:
# array([1254, 4963,    0, ..., 2284, 6269, 4361], dtype=int64)

# %%
data["youtube"].unique()
# Out:
# array([0], dtype=int64)

# %%
data['avg_session_time'].unique()
# Out:
# array([722.66666667, 445.21428571, 787.5       , ..., 122.71428571,
#        295.33333333, 484.17241379])

# %%
data['avg_session_time_page'].unique()
# Out:
# array([139.33333333, 177.25      ,   0.        , ..., 396.45454545,
#         71.91666667, 149.03571429])

# %%
data['last_visitId'].unique()
# Out:
# array([1619809803, 1619867532, 1617893676, ..., 1619785032, 1619233350,
#        1619790770], dtype=int64)

# %%
data['latest_visit_id'].unique()
# Out:
# array([1619809803, 1619867532, 1617893676, ..., 1619785032, 1619233350,
#        1619790770], dtype=int64)

# %%
data['latest_source'].unique()
# Out:
# array(['gulfnews', 'google', 'Pricena_AE', 'facebook', 'criteo', 'yaoota',
#        'Pricena_AE_Home'], dtype=object)

# %%
data['visits_per_day'].unique()
# Out:
# array([ 66.33333333,  73.48      ,  37.375     , ...,  44.26086957,
#         32.72      , 398.06451613])

# %%
data['latest_source'].unique()
# Out:
# array(['gulfnews', 'google', 'Pricena_AE', 'facebook', 'criteo', 'yaoota',
#        'Pricena_AE_Home'], dtype=object)

# %%
data['earliest_medium'].unique()
# Out:
# array(['app', '(none)', 'cpc', 'inapp', 'push', 'sms', 'channelsight',
#        'email', 'coupon', 'organic', 'search', 'cartpush',
#        'reactivationpush', 'signupinapp', 'nosignuppush', 'WhatsApp',
#        'referral', 'SocialMedia'], dtype=object)

# %%
data['latest_medium'].unique()
# Out:
# array(['app', 'cpc'], dtype=object)

# %%
data['time_on_site'].unique()
# Out:
# array([  5617,  77417,   1576, ..., 159304,   3912,   1212], dtype=int64)

# %%
data['target_date'].unique()
# Out:
# array(['2021-01-01'], dtype=object)

# %%
data['last_visitId'].value_counts()
# Out:
# last_visitId
# 1619841127    219
# 1619486852    127
# 1615751894    125
# 1619792335    123
# 1619871181    123
#              ...
# 1619799908      1
# 1617349939      1
# 1619714110      1
# 1619878633      1
# 1619763013      1
# Name: count, Length: 9093, dtype: int64

# %%
data['latest_visit_id'].value_counts()
# Out:
# latest_visit_id
# 1619841127    219
# 1619486852    127
# 1615751894    125
# 1619792335    123
# 1619871181    123
#              ...
# 1619799908      1
# 1617349939      1
# 1619714110      1
# 1619878633      1
# 1619763013      1
# Name: count, Length: 9093, dtype: int64

# %%
data['visitId_threshold'].value_counts()
# Out:
# visitId_threshold
# 1617249127    219
# 1616894852    127
# 1613159894    125
# 1617200335    123
# 1617279181    123
#              ...
# 1617207908      1
# 1614757939      1
# 1617122110      1
# 1617286633      1
# 1617171013      1
# Name: count, Length: 9093, dtype: int64

# %%
data['earliest_visit_id'].value_counts()
# Out:
# earliest_visit_id
# 1617162646    127
# 1613895482    125
# 1617204142    123
# 1618046777    123
# 1617369013    122
#              ...
# 1616242502      1
# 1617646992      1
# 1619842886      1
# 1617347654      1
# 1617357624      1
# Name: count, Length: 9160, dtype: int64

# %%
data['days_since_first_visit'].unique()
# Out:
# array([17, 24,  7,  1, 29, 26, 25, 28, 11, 22,  8, 27, 20,  0, 30, 21, 19,
#        15, 14, 12, 18, 13, 23, 10,  2,  6,  9,  3, 16,  5,  4],
#       dtype=int64)

# %%
data['bounces'].unique()
# Out:
# array([ 0, 14,  2,  1,  4, 10,  3,  6], dtype=int64)

# %%
data['latest_keyword'].unique()
# Out:
# array(['(not set)', '(automatic matching)', 'custom0==marketplace&+id==*',
#        'custom0==marketplace', 'custom0==food', 'custom0==nonfood',
#        'dxb_brd_all_20201221_crfnow', 'brd_brd_all_20210321_mp_combined',
#        '6w4xm8tV5OEkxlJc', 'id==190199246850',
#        'brd_brd_all_20201105_mp_t500push',
#        '(Remarketing/Content targeting)', 'carrefour online',
#        'Dynamic Search Ads', 'id==759068962248', 'id==1025754',
#        'carrfour', 'id==8844901224606', 'VR-iFlrG_M7WplFj',
#        'n_HbNfLo8ozmQSW1', 'id==1452885', 'carrefour', 'carrefour uae',
#        'brd_rak_all_20210421_fnf_combined', 'a6e5ivISlBaLZNFl',
#        'brd_brd_all_20200727_mp_combined', 'id==1250047', 'id==1551754',
#        'id==1313654', 'id==1630353', 'id==711719399308', 'id==1313655',
#        '+almarai +cheese', 'custom2==c4now', 'photo frames',
#        'id==1603515', 'brd_shj_20210421_fnf_combined', 'id==1004305',
#        'carrefour offers', 'id==1084479', 'id==1514202',
# ...

# %%
data.columns
# Out:
# Index(['count_session', 'count_hit', 'channelGrouping', 'totals_newVisits',
#        'device_browser', 'device_operatingSystem', 'device_isMobile',
#        'device_deviceCategory', 'geoNetwork_region', 'geoNetwork_latitude',
#        'geoNetwork_longitude', 'historic_session', 'historic_session_page',
#        'youtube', 'avg_session_time', 'avg_session_time_page',
#        'single_page_rate', 'sessionQualityDim', 'last_visitId',
#        'latest_visit_id', 'visitId_threshold', 'earliest_visit_id',
#        'earliest_visit_number', 'latest_visit_number', 'time_earliest_visit',
#        'time_latest_visit', 'avg_visit_time', 'days_since_last_visit',
#        'days_since_first_visit', 'visits_per_day', 'bounce_rate',
#        'earliest_source', 'latest_source', 'earliest_medium', 'latest_medium',
#        'earliest_keyword', 'latest_keyword', 'earliest_isTrueDirect',
#        'latest_isTrueDirect', 'num_interactions', 'bounces', 'time_on_site',
# ...

# %%
# COLUMN DROP

# %%
column_to_drop = ['count_session',"geoNetwork_latitude",'historic_session_page','avg_session_time_page','sessionQualityDim','avg_session_time',"geoNetwork_longitude","device_operatingSystem",'device_browser',"last_visitId","visitId_threshold","earliest_visit_id","earliest_visit_number",'time_earliest_visit','days_since_last_visit','days_since_first_visit','earliest_source','earliest_medium','earliest_keyword','earliest_isTrueDirect',"num_interactions",'target_date',"products_array"]

data.drop(column_to_drop, axis=1, inplace=True)

# %%
data.shape
# Out:
# (100000, 23)

# %%
data
# Out:
#        count_hit channelGrouping  totals_newVisits  device_isMobile  \
# 0           1194         (Other)                 0             True
# 1           1194         (Other)                 0             True
# 2           1816     Paid Search                 0             True
# 3            299     Paid Search                 0             True
# 4            299     Paid Search                 0             True
# ...          ...             ...               ...              ...
# 99995      12340     Paid Search                 0             True
# 99996      12340     Paid Search                 0             True
# 99997      12340     Paid Search                 0             True
# 99998      12340     Paid Search                 0             True
# 99999      12340     Paid Search                 0             True
#
#       device_deviceCategory geoNetwork_region  historic_session  youtube  \
# 0                    mobile           Sharjah              6504        0
# ...

# %%
data.isna().sum()
# Out:
# count_hit                0
# channelGrouping          0
# totals_newVisits         0
# device_isMobile          0
# device_deviceCategory    0
# geoNetwork_region        0
# historic_session         0
# youtube                  0
# single_page_rate         0
# latest_visit_id          0
# latest_visit_number      0
# time_latest_visit        0
# avg_visit_time           0
# visits_per_day           0
# bounce_rate              0
# latest_source            0
# latest_medium            0
# latest_keyword           0
# latest_isTrueDirect      0
# bounces                  0
# time_on_site             0
# transactionRevenue       0
# has_converted            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['count_hit', 'channelGrouping', 'totals_newVisits', 'device_isMobile',
#        'device_deviceCategory', 'geoNetwork_region', 'historic_session',
#        'youtube', 'single_page_rate', 'latest_visit_id', 'latest_visit_number',
#        'time_latest_visit', 'avg_visit_time', 'visits_per_day', 'bounce_rate',
#        'latest_source', 'latest_medium', 'latest_keyword',
#        'latest_isTrueDirect', 'bounces', 'time_on_site', 'transactionRevenue',
#        'has_converted'],
#       dtype='object')

# %%
def plot(data, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=data, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=data, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=data, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['count_hit', 'channelGrouping', 'totals_newVisits', 'device_isMobile',
       'device_deviceCategory', 'geoNetwork_region', 'historic_session',
       'youtube', 'single_page_rate', 'latest_visit_id', 'latest_visit_number',
       'time_latest_visit', 'avg_visit_time', 'visits_per_day', 'bounce_rate',
       'latest_source', 'latest_medium', 'latest_keyword',
       'latest_isTrueDirect', 'bounces', 'time_on_site', 'transactionRevenue',
       'has_converted']:
    plot(data, i)

# %%
data
# Out:
#        count_hit channelGrouping  totals_newVisits  device_isMobile  \
# 0           1194         (Other)                 0             True
# 1           1194         (Other)                 0             True
# 2           1816     Paid Search                 0             True
# 3            299     Paid Search                 0             True
# 4            299     Paid Search                 0             True
# ...          ...             ...               ...              ...
# 99995      12340     Paid Search                 0             True
# 99996      12340     Paid Search                 0             True
# 99997      12340     Paid Search                 0             True
# 99998      12340     Paid Search                 0             True
# 99999      12340     Paid Search                 0             True
#
#       device_deviceCategory geoNetwork_region  historic_session  youtube  \
# 0                    mobile           Sharjah              6504        0
# ...

# %%
data['device_deviceCategory'].unique()
# Out:
# array(['mobile', 'desktop', 'tablet'], dtype=object)

# %%
dis_count = data['channelGrouping'][data['channelGrouping']=='Display'].count()
dis_count
# Out:
# 12050

# %%
paid_count=data['channelGrouping'][data['channelGrouping']=='Paid Search'].count()
paid_count
# Out:
# 87948

# %%
sns.countplot(x="totals_newVisits", data=data)
plt.title(" Variable")
plt.show()

# %%
sns.countplot(x="device_isMobile", data=data)
plt.title(" Variable")
plt.show()

# %%
sns.countplot(x="device_deviceCategory", data=data)
plt.title(" Variable")
plt.show()

# %%
sns.barplot(x="geoNetwork_region", data=data)
plt.title(" Variable")
plt.show()

# %%
#checking unique values for each variable.
for i in data.columns:
    print("no of unique values in ",i,"is",data[i].nunique())
# Out:
# no of unique values in  count_hit is 4506
# no of unique values in  channelGrouping is 3
# no of unique values in  totals_newVisits is 2
# no of unique values in  device_isMobile is 2
# no of unique values in  device_deviceCategory is 3
# no of unique values in  geoNetwork_region is 91
# no of unique values in  historic_session is 6979
# no of unique values in  youtube is 1
# no of unique values in  single_page_rate is 493
# no of unique values in  latest_visit_id is 9093
# no of unique values in  latest_visit_number is 694
# no of unique values in  time_latest_visit is 1356
# no of unique values in  avg_visit_time is 24
# no of unique values in  visits_per_day is 7794
# no of unique values in  bounce_rate is 92
# no of unique values in  latest_source is 7
# no of unique values in  latest_medium is 2
# no of unique values in  latest_keyword is 572
# no of unique values in  latest_isTrueDirect is 2
# no of unique values in  bounces is 8
# no of unique values in  time_on_site is 6009
# ...

# %%
data.describe()
# Out:
#            count_hit  totals_newVisits  historic_session   youtube  \
# count  100000.000000     100000.000000     100000.000000  100000.0
# mean     3671.722790          0.020380       9692.262300       0.0
# std      4627.338737          0.141297      12891.629368       0.0
# min         2.000000          0.000000          2.000000       0.0
# 25%       971.000000          0.000000       2694.000000       0.0
# 50%      2209.000000          0.000000       5864.000000       0.0
# 75%      4812.000000          0.000000      11858.000000       0.0
# max     48744.000000          1.000000     181715.000000       0.0
#
#        single_page_rate  latest_visit_id  latest_visit_number  \
# count     100000.000000     1.000000e+05        100000.000000
# mean           0.868155     1.619194e+09           209.919720
# std            0.274665     1.417897e+06          2580.841182
# min            0.000000     1.609492e+09             1.000000
# ...

# %%
data["has_converted"].value_counts()
# Out:
# has_converted
# 1    51727
# 0    48273
# Name: count, dtype: int64

# %%
print("percentage of not converted and converted\n",data["has_converted"].value_counts()/len(data)*100)
# Out:
# percentage of not converted and converted
#  has_converted
# 1    51.727
# 0    48.273
# Name: count, dtype: float64

# %%
print("percentage of device\n",data["device_deviceCategory"].value_counts()/len(data)*100)
# Out:
# percentage of device
#  device_deviceCategory
# mobile     93.245
# desktop     6.414
# tablet      0.341
# Name: count, dtype: float64

# %%
#visualize the has converted count for both device_deviceCategory
sns.countplot(x="device_deviceCategory", hue="has_converted",data=data)
# Out:
# <Axes: xlabel='device_deviceCategory', ylabel='count'>

# %%
print("percentage of device\n",data["geoNetwork_region"].value_counts()/len(data)*100)
# Out:
# percentage of device
#  geoNetwork_region
# Dubai                    51.481
# Abu Dhabi                33.799
# Sharjah                   7.214
# Ajman                     4.157
# Ras al Khaimah            1.298
#                           ...
# Western Province          0.001
# Nabatiyeh Governorate     0.001
# Western Cape              0.001
# Quebec                    0.001
# Chandigarh                0.001
# Name: count, Length: 91, dtype: float64

# %%
#visualize the converted count for the country wise
sns.histplot(x="geoNetwork_region", hue="has_converted",data=data)
# Out:
# <Axes: xlabel='geoNetwork_region', ylabel='Count'>

# %%
import sweetviz as sv

# %%
# Create the EDA report
report = sv.analyze(data)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:04 -> (00:00 left)

# %%
# Display the report in a Jupyter notebook or save it to an HTML file
report.show_html("sweetviz_report.html")
# Out:
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
